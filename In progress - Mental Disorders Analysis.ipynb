# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
mental = pd.read_csv('C:/Users/abhin/OneDrive/Documents/data science kaggle/illness.csv')
mental.info()
mental = mental.round(2)
mental.columns = ['Name', 'Code', 'Year','Schizophrenia Disorders','Depression Disorders','Anxiety Disorders','Bipolar Disorders','Eating Disorders' ]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1410 entries, 0 to 1409
# Data columns (total 8 columns):
#  #   Column                                                                             Non-Null Count  Dtype
# ---  ------                                                                             --------------  -----
#  0   Entity                                                                             1410 non-null   object
#  1   Code                                                                               1350 non-null   object
#  2   Year                                                                               1410 non-null   int64
#  3   Schizophrenia disorders (share of population) - Sex: Both - Age: Age-standardized  1410 non-null   float64
#  4   Depressive disorders (share of population) - Sex: Both - Age: Age-standardized     1410 non-null   float64
# ...

# %%
mental.describe().round(2)
Names = 'Name'

unique_values = mental[Names].unique()

print("Unique Values in '{}' Column:".format(Names))
print(unique_values)

column_name = 'Name'


name_counts = mental[column_name].value_counts()


print("Value Counts in '{}' Column:".format(column_name))
print(name_counts)
# Out:
# Unique Values in 'Name' Column:
# ['Afghanistan' 'Africa (IHME GBD)' 'Albania' 'Algeria'
#  'America (IHME GBD)' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Australia' 'Bangladesh' 'Canada'
#  'China' 'Egypt' 'Finland' 'France' 'Georgia' 'Germany' 'Greenland'
#  'Hungary' 'Iceland' 'India' 'Indonesia' 'Iran' 'Iraq' 'Israel' 'Italy'
#  'Jamaica' 'Japan' 'Philippines' 'Poland' 'Russia' 'South Africa'
#  'South Korea' 'Spain' 'Sri Lanka' 'Sweden' 'Switzerland' 'Syria' 'Taiwan'
#  'Thailand' 'Turkey' 'Ukraine' 'United Arab Emirates' 'United Kingdom'
#  'United States']
# Value Counts in 'Name' Column:
# Name
# Afghanistan             30
# Spain                   30
# Israel                  30
# Italy                   30
# Jamaica                 30
# Japan                   30
# Philippines             30
# Poland                  30
# Russia                  30
# South Africa            30
# South Korea             30
# Sri Lanka               30
# ...

# %%
mental.describe().columns
# Out:
# Index(['Year', 'Schizophrenia Disorders', 'Depression Disorders',
#        'Anxiety Disorders', 'Bipolar Disorders', 'Eating Disorders'],
#       dtype='object')

# %%
mental.describe().columns
# Out:
# Index(['Year', 'Schizophrenia Disorders', 'Depression Disorders',
#        'Anxiety Disorders', 'Bipolar Disorders', 'Eating Disorders'],
#       dtype='object')

# %%
df_char = mental[['Name' ,'Code']]
df_num = mental[['Year','Schizophrenia Disorders','Depression Disorders','Anxiety Disorders','Bipolar Disorders','Eating Disorders' ]
]

# %%
for i in df_num.columns:
    plt.hist(df_num[i])
    plt.title(i)
    plt.show()

# %%
correlation_matrix = df_num.corr()
correlation_matrix = correlation_matrix.round(2)
print(correlation_matrix)
sns.heatmap(correlation_matrix)
# Out:
#                          Year  Schizophrenia Disorders  Depression Disorders  \
# Year                     1.00                     0.02                 -0.05
# Schizophrenia Disorders  0.02                     1.00                 -0.08
# Depression Disorders    -0.05                    -0.08                  1.00
# Anxiety Disorders        0.04                     0.12                  0.31
# Bipolar Disorders        0.01                     0.00                  0.30
# Eating Disorders         0.08                     0.45                  0.23
#
#                          Anxiety Disorders  Bipolar Disorders  \
# Year                                  0.04               0.01
# Schizophrenia Disorders               0.12               0.00
# Depression Disorders                  0.31               0.30
# Anxiety Disorders                     1.00               0.54
# Bipolar Disorders                     0.54               1.00
# ...

# %%
column_name = 'Name'

name_counts = mental[column_name].value_counts().reset_index()
name_counts.columns = ['Name', 'Name_Counts']
mental_with_counts = pd.merge(mental, name_counts, on='Name')


print(mental_with_counts)
# Out:
#                Name Code  Year  Schizophrenia Disorders  Depression Disorders  \
# 0       Afghanistan  AFG  1990                     0.22                  5.00
# 1       Afghanistan  AFG  1991                     0.22                  4.99
# 2       Afghanistan  AFG  1992                     0.22                  4.98
# 3       Afghanistan  AFG  1993                     0.22                  4.98
# 4       Afghanistan  AFG  1994                     0.22                  4.98
# ...             ...  ...   ...                      ...                   ...
# 1405  United States  USA  2015                     0.44                  4.38
# 1406  United States  USA  2016                     0.44                  4.37
# 1407  United States  USA  2017                     0.43                  4.37
# 1408  United States  USA  2018                     0.43                  4.37
# 1409  United States  USA  2019                     0.43                  4.38
#
# ...

# %%
As_region = 'Asia'
As_category1 = 'High GDP'
As_countries1 = ['China', 'Japan']
As_category2 = 'Medium GDP'
As_countries2 = ['India', 'South Korea', 'Taiwan']
As_category3 = 'Low GDP'
As_countries3 = ['Bangladesh', 'Indonesia', 'Philippines', 'Thailand']
subset_dataframes = {}

# High gdp
As_High = f"{As_region}_{As_category1}"
As1_df = mental[mental['Name'].isin(As_countries1)].copy() 
subset_dataframes[As_High] = As1_df
print(As1_df)
#Mid gdp
As_Mid = f"{As_region}_{As_category2}"
As2_df = mental[mental['Name'].isin(As_countries2)].copy()
subset_dataframes[As_Mid] = As2_df
print(As2_df)
#low gdp
As_Low = f"{As_region}_{As_category3}"
As3_df = mental[mental['Name'].isin(As_countries3)].copy()  
subset_dataframes[As_Low] = As3_df
print(As3_df)
# Out:
#       Name Code  Year  Schizophrenia Disorders  Depression Disorders  \
# 390  China  CHN  1990                     0.30                  3.00
# 391  China  CHN  1991                     0.30                  3.05
# 392  China  CHN  1992                     0.30                  3.09
# 393  China  CHN  1993                     0.30                  3.12
# 394  China  CHN  1994                     0.30                  3.13
# 395  China  CHN  1995                     0.30                  3.12
# 396  China  CHN  1996                     0.30                  3.10
# 397  China  CHN  1997                     0.30                  3.05
# 398  China  CHN  1998                     0.30                  3.00
# 399  China  CHN  1999                     0.30                  2.94
# 400  China  CHN  2000                     0.30                  2.91
# 401  China  CHN  2001                     0.30                  2.90
# 402  China  CHN  2002                     0.30                  2.89
# ...

# %%
Eu_region = 'Europe'
Eu_category1 = 'High GDP'
Eu_countries1 = ['Germany', 'United Kingdom', 'France', 'Italy']
Eu_category2 = 'Medium GDP'
Eu_countries2 = ['Spain', 'Switzerland', 'Sweden']
Eu_category3 = 'Low GDP'
Eu_countries3 = ['Albania', 'Finland', 'Georgia', 'Hungary', 'Iceland', 'Poland', 'Russia', 'Ukraine']
subset_dataframes = {}

# High gdp
Eu_High = f"{Eu_region}_{Eu_category1}"
Eu1_df = mental[mental['Name'].isin(Eu_countries1)].copy() 
subset_dataframes[Eu_High] = Eu1_df
print(Eu1_df)
#Mid gdp
Eu_Mid= f"{Eu_region}_{Eu_category2}"
Eu2_df = mental[mental['Name'].isin(Eu_countries2)].copy() 
subset_dataframes[Eu_Mid] = Eu2_df
print(Eu2_df)
#low gdp
Eu_Low = f"{Eu_region}_{Eu_category3}"
Eu3_df = mental[mental['Name'].isin(Eu_countries3)].copy() 
subset_dataframes[Eu_Low] = Eu3_df
print(Eu3_df)
# Out:
#                 Name Code  Year  Schizophrenia Disorders  \
# 480           France  FRA  1990                     0.27
# 481           France  FRA  1991                     0.27
# 482           France  FRA  1992                     0.27
# 483           France  FRA  1993                     0.27
# 484           France  FRA  1994                     0.27
# ...              ...  ...   ...                      ...
# 1375  United Kingdom  GBR  2015                     0.27
# 1376  United Kingdom  GBR  2016                     0.27
# 1377  United Kingdom  GBR  2017                     0.27
# 1378  United Kingdom  GBR  2018                     0.27
# 1379  United Kingdom  GBR  2019                     0.25
#
#       Depression Disorders  Anxiety Disorders  Bipolar Disorders  \
# 480                   4.44               6.26               0.90
# 481                   4.35               6.21               0.90
# 482                   4.27               6.17               0.90
# ...

# %%
Me_region = 'Middle East'
Me_category1 = 'High GDP'
Me_countries1 = ['United Arab Emirates', 'Israel']
Me_category2 = 'Medium GDP'
Me_countries2 = ['Iran', 'Turkey']
Me_category3 = 'Low GDP'
Me_countries3 = ['Afghanistan', 'Iraq', 'Syria']
subset_dataframes = {}

# High GDP
Me_High = f"{Me_region}_{Me_category1}"
Me1_df = mental[mental['Name'].isin(Me_countries1)].copy() 
subset_dataframes[Me_High] = Me1_df
print(Me1_df)

# Medium GDP
Me_Mid= f"{Me_region}_{Me_category2}"
Me2_df = mental[mental['Name'].isin(Me_countries2)].copy() 
subset_dataframes[Me_Mid] = Me2_df
print(Me2_df)

# Low GDP
Me_Low = f"{Me_region}_{Me_category3}"
Me3_df = mental[mental['Name'].isin(Me_countries3)].copy() 
subset_dataframes[Me_Low] = Me3_df
print(Me3_df)
# Out:
#                       Name Code  Year  Schizophrenia Disorders  \
# 780                 Israel  ISR  1990                     0.31
# 781                 Israel  ISR  1991                     0.30
# 782                 Israel  ISR  1992                     0.30
# 783                 Israel  ISR  1993                     0.30
# 784                 Israel  ISR  1994                     0.30
# 785                 Israel  ISR  1995                     0.30
# 786                 Israel  ISR  1996                     0.30
# 787                 Israel  ISR  1997                     0.30
# 788                 Israel  ISR  1998                     0.30
# 789                 Israel  ISR  1999                     0.30
# 790                 Israel  ISR  2000                     0.31
# 791                 Israel  ISR  2001                     0.31
# 792                 Israel  ISR  2002                     0.31
# 793                 Israel  ISR  2003                     0.30
# ...

# %%
Af_region = 'Africa'
Af_category1 = 'High GDP'
Af_countries1 = ['South Africa']
Af_category2 = 'Medium GDP'
Af_countries2 = ['Algeria']
Af_category3 = 'Low GDP'
Af_countries3 = ['Angola']
subset_dataframes = {}

# High GDP
Af_High = f"{Af_region}_{Af_category1}"
Af1_df = mental[mental['Name'].isin(Af_countries1)].copy() 
subset_dataframes[Af_High] = Af1_df
print(Af1_df)

# Medium GDP
Af_Mid= f"{Af_region}_{Af_category2}"
Af2_df = mental[mental['Name'].isin(Af_countries2)].copy() 
subset_dataframes[Af_Mid] = Af2_df
print(Af2_df)

# Low GDP
Af_Low = f"{Af_region}_{Af_category3}"
Af3_df = mental[mental['Name'].isin(Af_countries3)].copy() 
subset_dataframes[Af_Low] = Af3_df
print(Af3_df)
# Out:
#               Name Code  Year  Schizophrenia Disorders  Depression Disorders  \
# 990   South Africa  ZAF  1990                     0.22                  4.28
# 991   South Africa  ZAF  1991                     0.22                  4.23
# 992   South Africa  ZAF  1992                     0.22                  4.19
# 993   South Africa  ZAF  1993                     0.22                  4.15
# 994   South Africa  ZAF  1994                     0.22                  4.13
# 995   South Africa  ZAF  1995                     0.22                  4.11
# 996   South Africa  ZAF  1996                     0.22                  4.10
# 997   South Africa  ZAF  1997                     0.22                  4.10
# 998   South Africa  ZAF  1998                     0.22                  4.09
# 999   South Africa  ZAF  1999                     0.22                  4.08
# 1000  South Africa  ZAF  2000                     0.22                  4.08
# ...

# %%
Am_region = 'Americas'
Am_category1 = 'High GDP'
Am_countries1 = ['United States', 'Canada']
Am_category2 = 'Medium GDP'
Am_countries2 = ['Argentina']
Am_category3 = 'Low GDP'
Am_countries3 = ['Jamaica', 'America (IHME GBD)', 'American Samoa']
subset_dataframes = {}

# High GDP
Am_High = f"{Am_region}_{Am_category1}"
Am1_df = mental[mental['Name'].isin(Am_countries1)].copy() 
subset_dataframes[Am_High] = Am1_df
print(Am1_df)

# Medium GDP
Am_Mid= f"{Am_region}_{Am_category2}"
Am2_df = mental[mental['Name'].isin(Am_countries2)].copy() 
subset_dataframes[Am_Mid] = Am2_df
print(Am2_df)

# Low GDP
Am_Low = f"{Am_region}_{Am_category3}"
Am3_df = mental[mental['Name'].isin(Am_countries3)].copy() 
subset_dataframes[Am_Low] = Am3_df
print(Am3_df)
# Out:
#                Name Code  Year  Schizophrenia Disorders  Depression Disorders  \
# 360          Canada  CAN  1990                     0.29                  3.30
# 361          Canada  CAN  1991                     0.29                  3.31
# 362          Canada  CAN  1992                     0.29                  3.33
# 363          Canada  CAN  1993                     0.29                  3.35
# 364          Canada  CAN  1994                     0.29                  3.37
# 365          Canada  CAN  1995                     0.29                  3.38
# 366          Canada  CAN  1996                     0.29                  3.40
# 367          Canada  CAN  1997                     0.29                  3.43
# 368          Canada  CAN  1998                     0.29                  3.46
# 369          Canada  CAN  1999                     0.29                  3.48
# 370          Canada  CAN  2000                     0.29                  3.48
# ...

# %%
As_region = 'Asia'
As_category1 = 'High GDP'
As_countries1 = ['China', 'Japan']
As_category2 = 'Medium GDP'
As_countries2 = ['India', 'South Korea', 'Taiwan']
As_category3 = 'Low GDP'
As_countries3 = ['Bangladesh', 'Indonesia', 'Philippines', 'Thailand']
subset_dataframes = {}

# High gdp
As_High = f"{As_region}_{As_category1}"
As1_df = mental[mental['Name'].isin(As_countries1)].copy() 
subset_dataframes[As_High] = As1_df
print(As1_df)
#Mid gdp
As_Mid = f"{As_region}_{As_category2}"
As2_df = mental[mental['Name'].isin(As_countries2)].copy()
subset_dataframes[As_Mid] = As2_df
print(As2_df)
#low gdp
As_Low = f"{As_region}_{As_category3}"
As3_df = mental[mental['Name'].isin(As_countries3)].copy()  
subset_dataframes[As_Low] = As3_df
print(As3_df)
# Out:
#       Name Code  Year  Schizophrenia Disorders  Depression Disorders  \
# 390  China  CHN  1990                     0.30                  3.00
# 391  China  CHN  1991                     0.30                  3.05
# 392  China  CHN  1992                     0.30                  3.09
# 393  China  CHN  1993                     0.30                  3.12
# 394  China  CHN  1994                     0.30                  3.13
# 395  China  CHN  1995                     0.30                  3.12
# 396  China  CHN  1996                     0.30                  3.10
# 397  China  CHN  1997                     0.30                  3.05
# 398  China  CHN  1998                     0.30                  3.00
# 399  China  CHN  1999                     0.30                  2.94
# 400  China  CHN  2000                     0.30                  2.91
# 401  China  CHN  2001                     0.30                  2.90
# 402  China  CHN  2002                     0.30                  2.89
# ...

# %%
As1_df = subset_dataframes['Asia_High GDP']
As1_df = As1_df[(As1_df['Year'] >= 1990) & (As1_df['Year'] <= 2000)]  


As1_df_china = As1_df[As1_df['Name'] == 'China']
As1_df_japan = As1_df[As1_df['Name'] == 'Japan']

plt.figure(figsize=(10, 6))

plt.bar(As1_df_china['Year'], As1_df_china['Anxiety Disorders'], color='lightcoral', edgecolor='black', label='China')


plt.bar(As1_df_japan['Year'], As1_df_japan['Anxiety Disorders'], color='lightsteelblue', edgecolor='black', label='Japan')

plt.title('Anxiety Disorders in Asia (High GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()



plt.figure(figsize=(10, 6))

plt.bar(As1_df_china['Year'], As1_df_china['Depression Disorders'], color='lightcoral', edgecolor='black', label='China')


plt.bar(As1_df_japan['Year'], As1_df_japan['Depression Disorders'], color='lightsteelblue', edgecolor='black', label='Japan')

plt.title('Depressive Disorders in Asia (High GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Depressive Disorders')
plt.show()

plt.figure(figsize=(10, 6))

plt.bar(As1_df_china['Year'], As1_df_china['Schizophrenia Disorders'], color='lightcoral', edgecolor='black', label='China')
plt.bar(As1_df_japan['Year'], As1_df_japan['Schizophrenia Disorders'], color='lightsteelblue', edgecolor='black', label='Japan')

plt.title('Schizophrenia Disorders in Asia (High GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.bar(As1_df_japan['Year'], As1_df_japan['Bipolar Disorders'], color='lightsteelblue', edgecolor='black', label='Japan')
plt.bar(As1_df_china['Year'], As1_df_china['Bipolar Disorders'], color='lightcoral', edgecolor='black', label='China')
plt.title('Bipolar Disorders in Asia (High GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))
plt.bar(As1_df_japan['Year'], As1_df_japan['Eating Disorders'], color='lightsteelblue', edgecolor='black', label='Japan')
plt.bar(As1_df_china['Year'], As1_df_china['Eating Disorders'], color='lightcoral', edgecolor='black', label='China')
plt.title('Eating Disorders in Asia (High GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()

# %%
# For Anxiety Disorders
As2_df = subset_dataframes['Asia_Medium GDP']
As2_df = As2_df[(As2_df['Year'] >= 1990) & (As2_df['Year'] <= 2000)]  

As2_df_india = As2_df[As2_df['Name'] == 'India']
As2_df_skorea = As2_df[As2_df['Name'] == 'South Korea']
As2_df_taiwan = As2_df[As2_df['Name'] == 'Taiwan']

plt.figure(figsize=(10, 6))

plt.bar(As2_df_taiwan['Year'], As2_df_taiwan['Anxiety Disorders'], color='red', edgecolor='black', label='Taiwan')
plt.bar(As2_df_skorea['Year'], As2_df_skorea['Anxiety Disorders'], color='lightblue', edgecolor='black', label='South Korea')
plt.bar(As2_df_india['Year'], As2_df_india['Anxiety Disorders'], color='lightgreen', edgecolor='black', label='India')

plt.title('Anxiety Disorders in Asia (Medium GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()

# For Depressive Disorders
plt.figure(figsize=(10, 6))

plt.bar(As2_df_india['Year'], As2_df_india['Depression Disorders'], color='lightgreen', edgecolor='black', label='India')
plt.bar(As2_df_taiwan['Year'], As2_df_taiwan['Depression Disorders'], color='red', edgecolor='black', label='Taiwan')
plt.bar(As2_df_skorea['Year'], As2_df_skorea['Depression Disorders'], color='lightblue', edgecolor='black', label='South Korea')

plt.title('Depressive Disorders in Asia (Medium GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Depressive Disorders')
plt.legend()
plt.show()

# For Schizophrenia Disorders
plt.figure(figsize=(10, 6))

plt.bar(As2_df_taiwan['Year'], As2_df_taiwan['Schizophrenia Disorders'], color='red', edgecolor='black', label='Taiwan')
plt.bar(As2_df_skorea['Year'], As2_df_skorea['Schizophrenia Disorders'], color='lightblue', edgecolor='black', label='South Korea')
plt.bar(As2_df_india['Year'], As2_df_india['Schizophrenia Disorders'], color='lightgreen', edgecolor='black', label='India')

plt.title('Schizophrenia Disorders in Asia (Medium GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

# For Bipolar Disorders
plt.figure(figsize=(10, 6))

plt.bar(As2_df_skorea['Year'], As2_df_skorea['Bipolar Disorders'], color='lightblue', edgecolor='black', label='South Korea')
plt.bar(As2_df_india['Year'], As2_df_india['Bipolar Disorders'], color='lightgreen', edgecolor='black', label='India')
plt.bar(As2_df_taiwan['Year'], As2_df_taiwan['Bipolar Disorders'], color='red', edgecolor='black', label='Taiwan')

plt.title('Bipolar Disorders in Asia (Medium GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()

# For Eating Disorders
plt.figure(figsize=(10, 6))

plt.bar(As2_df_skorea['Year'], As2_df_skorea['Eating Disorders'], color='lightblue', edgecolor='black', label='South Korea')
plt.bar(As2_df_taiwan['Year'], As2_df_taiwan['Eating Disorders'], color='red', edgecolor='black', label='Taiwan')
plt.bar(As2_df_india['Year'], As2_df_india['Eating Disorders'], color='lightgreen', edgecolor='black', label='India')

plt.title('Eating Disorders in Asia (Medium GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()

# %%
As3_df = subset_dataframes['Asia_Low GDP']
As3_df = As3_df[(As3_df['Year'] >= 1990) & (As3_df['Year'] <= 2000)]  

As3_df_bangladesh = As3_df[As3_df['Name'] == 'Bangladesh']
As3_df_indonesia = As3_df[As3_df['Name'] == 'Indonesia']
As3_df_philippines = As3_df[As3_df['Name'] == 'Philippines']
As3_df_thailand = As3_df[As3_df['Name'] == 'Thailand']

plt.figure(figsize=(10, 6))



plt.bar(As3_df_philippines['Year'], As3_df_philippines['Anxiety Disorders'], color='lightgreen', edgecolor='black', label='Philippines')
plt.bar(As3_df_indonesia['Year'], As3_df_indonesia['Anxiety Disorders'], color='lightblue', edgecolor='black', label='Indonesia')
plt.bar(As3_df_thailand['Year'], As3_df_thailand['Anxiety Disorders'], color='purple', edgecolor='black', label='Thailand')
plt.bar(As3_df_bangladesh['Year'], As3_df_bangladesh['Anxiety Disorders'], color='red', edgecolor='black', label='Bangladesh')
plt.title('Anxiety Disorders in Asia (Low GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()

# For Depressive Disorders
plt.figure(figsize=(10, 6))

plt.bar(As3_df_bangladesh['Year'], As3_df_bangladesh['Depression Disorders'], color='red', edgecolor='black', label='Bangladesh')


plt.bar(As3_df_philippines['Year'], As3_df_philippines['Depression Disorders'], color='lightgreen', edgecolor='black', label='Philippines')

plt.bar(As3_df_thailand['Year'], As3_df_thailand['Depression Disorders'], color='purple', edgecolor='black', label='Thailand')
plt.bar(As3_df_indonesia['Year'], As3_df_indonesia['Depression Disorders'], color='lightblue', edgecolor='black', label='Indonesia')
plt.title('Depressive Disorders in Asia (Low GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Depressive Disorders')
plt.legend()
plt.show()

# For Schizophrenia Disorders
plt.figure(figsize=(10, 6))


plt.bar(As3_df_thailand['Year'], As3_df_thailand['Schizophrenia Disorders'], color='purple', edgecolor='black', label='Thailand')

plt.bar(As3_df_indonesia['Year'], As3_df_indonesia['Schizophrenia Disorders'], color='lightblue', edgecolor='black', label='Indonesia')
plt.bar(As3_df_bangladesh['Year'], As3_df_bangladesh['Schizophrenia Disorders'], color='red', edgecolor='black', label='Bangladesh')
plt.bar(As3_df_philippines['Year'], As3_df_philippines['Schizophrenia Disorders'], color='lightgreen', edgecolor='black', label='Philippines')

plt.title('Schizophrenia Disorders in Asia (Low GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

# For Bipolar Disorders
plt.figure(figsize=(10, 6))

plt.bar(As3_df_bangladesh['Year'], As3_df_bangladesh['Bipolar Disorders'], color='red', edgecolor='black', label='Bangladesh')

plt.bar(As3_df_philippines['Year'], As3_df_philippines['Bipolar Disorders'], color='lightgreen', edgecolor='black', label='Philippines')

plt.bar(As3_df_thailand['Year'], As3_df_thailand['Bipolar Disorders'], color='purple', edgecolor='black', label='Thailand')

plt.bar(As3_df_indonesia['Year'], As3_df_indonesia['Bipolar Disorders'], color='lightblue', edgecolor='black', label='Indonesia')

plt.title('Bipolar Disorders in Asia (Low GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()


# For Eating Disorders
plt.figure(figsize=(10, 6))


plt.bar(As3_df_thailand['Year'], As3_df_thailand['Eating Disorders'], color='purple', edgecolor='black', label='Thailand')

plt.bar(As3_df_philippines['Year'], As3_df_philippines['Eating Disorders'], color='lightgreen', edgecolor='black', label='Philippines')
plt.bar(As3_df_bangladesh['Year'], As3_df_bangladesh['Eating Disorders'], color='red', edgecolor='black', label='Bangladesh')
plt.bar(As3_df_indonesia['Year'], As3_df_indonesia['Eating Disorders'], color='lightblue', edgecolor='black', label='Indonesia')

plt.title('Eating Disorders in Asia (Low GDP) - 1990 to 2000')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()

# %%
Me1_df_uae = Me1_df[Me1_df['Name'] == 'United Arab Emirates']
Me1_df_israel = Me1_df[Me1_df['Name'] == 'Israel']

plt.figure(figsize=(10, 6))

plt.bar(Me1_df_uae['Year'], Me1_df_uae['Anxiety Disorders'], color='lightcoral', edgecolor='black', label='United Arab Emirates')
plt.bar(Me1_df_israel['Year'], Me1_df_israel['Anxiety Disorders'], color='lightsteelblue', edgecolor='black', label='Israel')

plt.title('Anxiety Disorders in Middle East (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))

plt.bar(Me1_df_israel['Year'], Me1_df_israel['Depression Disorders'], color='lightsteelblue', edgecolor='black', label='Israel')

plt.bar(Me1_df_uae['Year'], Me1_df_uae['Depression Disorders'], color='lightcoral', edgecolor='black', label='United Arab Emirates')

plt.title('Depression Disorders in Middle East (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Depression Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))


plt.bar(Me1_df_israel['Year'], Me1_df_israel['Eating Disorders'], color='lightsteelblue', edgecolor='black', label='Israel')
plt.bar(Me1_df_uae['Year'], Me1_df_uae['Eating Disorders'], color='lightcoral', edgecolor='black', label='United Arab Emirates')

plt.title('Eating Disorders in Middle East (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))


plt.bar(Me1_df_israel['Year'], Me1_df_israel['Bipolar Disorders'], color='lightsteelblue', edgecolor='black', label='Israel')
plt.bar(Me1_df_uae['Year'], Me1_df_uae['Bipolar Disorders'], color='lightcoral', edgecolor='black', label='United Arab Emirates')

plt.title('Bipolar Disorders in Middle East (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))

plt.bar(Me1_df_israel['Year'], Me1_df_israel['Schizophrenia Disorders'], color='lightsteelblue', edgecolor='black', label='Israel')
plt.bar(Me1_df_uae['Year'], Me1_df_uae['Schizophrenia Disorders'], color='lightcoral', edgecolor='black', label='United Arab Emirates')
plt.title('Schizophrenia Disorders in Middle East (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

# %%
# Medium GDP
Me2_df_iran = Me2_df[Me2_df['Name'] == 'Iran']
Me2_df_turkey = Me2_df[Me2_df['Name'] == 'Turkey']

plt.figure(figsize=(10, 6))

plt.bar(Me2_df_iran['Year'], Me2_df_iran['Anxiety Disorders'], color='lightcoral', edgecolor='black', label='Iran')
plt.bar(Me2_df_turkey['Year'], Me2_df_turkey['Anxiety Disorders'], color='lightsteelblue', edgecolor='black', label='Turkey')

plt.title('Anxiety Disorders in Middle East (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))

plt.bar(Me2_df_iran['Year'], Me2_df_iran['Depression Disorders'], color='lightcoral', edgecolor='black', label='Iran')
plt.bar(Me2_df_turkey['Year'], Me2_df_turkey['Depression Disorders'], color='lightsteelblue', edgecolor='black', label='Turkey')

plt.title('Depression Disorders in Middle East (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Depression Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))


plt.bar(Me2_df_turkey['Year'], Me2_df_turkey['Eating Disorders'], color='lightsteelblue', edgecolor='black', label='Turkey')
plt.bar(Me2_df_iran['Year'], Me2_df_iran['Eating Disorders'], color='lightcoral', edgecolor='black', label='Iran')

plt.title('Eating Disorders in Middle East (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))

plt.bar(Me2_df_iran['Year'], Me2_df_iran['Bipolar Disorders'], color='lightcoral', edgecolor='black', label='Iran')
plt.bar(Me2_df_turkey['Year'], Me2_df_turkey['Bipolar Disorders'], color='lightsteelblue', edgecolor='black', label='Turkey')

plt.title('Bipolar Disorders in Middle East (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))


plt.bar(Me2_df_turkey['Year'], Me2_df_turkey['Schizophrenia Disorders'], color='lightsteelblue', edgecolor='black', label='Turkey')
plt.bar(Me2_df_iran['Year'], Me2_df_iran['Schizophrenia Disorders'], color='lightcoral', edgecolor='black', label='Iran')
plt.title('Schizophrenia Disorders in Middle East (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

# %%
Eu_region = 'Europe'
Eu_category1 = 'High GDP'
Eu_countries1 = ['Germany', 'United Kingdom', 'France', 'Italy']
Eu_category2 = 'Medium GDP'
Eu_countries2 = ['Spain', 'Switzerland', 'Sweden']
Eu_category3 = 'Low GDP'
Eu_countries3 = ['Albania', 'Finland', 'Georgia', 'Hungary', 'Iceland', 'Poland', 'Russia', 'Ukraine']
subset_dataframes = {}

# High gdp
Eu_High = f"{Eu_region}_{Eu_category1}"
Eu1_df = mental[mental['Name'].isin(Eu_countries1)].copy() 
subset_dataframes[Eu_High] = Eu1_df
#Mid gdp
Eu_Mid= f"{Eu_region}_{Eu_category2}"
Eu2_df = mental[mental['Name'].isin(Eu_countries2)].copy() 
subset_dataframes[Eu_Mid] = Eu2_df
#low gdp
Eu_Low = f"{Eu_region}_{Eu_category3}"
Eu3_df = mental[mental['Name'].isin(Eu_countries3)].copy() 
subset_dataframes[Eu_Low] = Eu3_df

Eu1_df_germany = Eu1_df[Eu1_df['Name'] == 'Germany']
Eu1_df_uk = Eu1_df[Eu1_df['Name'] == 'United Kingdom']
Eu1_df_france = Eu1_df[Eu1_df['Name'] == 'France']
Eu1_df_italy = Eu1_df[Eu1_df['Name'] == 'Italy']

plt.figure(figsize=(10, 6))


plt.bar(Eu1_df_france['Year'], Eu1_df_france['Anxiety Disorders'], color='lightgreen', edgecolor='black', label='France')

plt.bar(Eu1_df_germany['Year'], Eu1_df_germany['Anxiety Disorders'], color='lightcoral', edgecolor='black', label='Germany')

plt.bar(Eu1_df_italy['Year'], Eu1_df_italy['Anxiety Disorders'], color='lightpink', edgecolor='black', label='Italy')
plt.bar(Eu1_df_uk['Year'], Eu1_df_uk['Anxiety Disorders'], color='lightsteelblue', edgecolor='black', label='United Kingdom')
plt.title('Anxiety Disorders in Europe (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))


plt.bar(Eu1_df_uk['Year'], Eu1_df_uk['Depression Disorders'], color='lightsteelblue', edgecolor='black', label='United Kingdom')
plt.bar(Eu1_df_france['Year'], Eu1_df_france['Depression Disorders'], color='lightgreen', edgecolor='black', label='France')
plt.bar(Eu1_df_italy['Year'], Eu1_df_italy['Depression Disorders'], color='lightpink', edgecolor='black', label='Italy')
plt.bar(Eu1_df_germany['Year'], Eu1_df_germany['Depression Disorders'], color='lightcoral', edgecolor='black', label='Germany')

plt.title('Depressive Disorders in Europe (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Depressive Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))


plt.bar(Eu1_df_italy['Year'], Eu1_df_italy['Schizophrenia Disorders'], color='lightpink', edgecolor='black', label='Italy')
plt.bar(Eu1_df_france['Year'], Eu1_df_france['Schizophrenia Disorders'], color='lightgreen', edgecolor='black', label='France')
plt.bar(Eu1_df_germany['Year'], Eu1_df_germany['Schizophrenia Disorders'], color='lightcoral', edgecolor='black', label='Germany')
plt.bar(Eu1_df_uk['Year'], Eu1_df_uk['Schizophrenia Disorders'], color='lightsteelblue', edgecolor='black', label='United Kingdom')
plt.title('Schizophrenia Disorders in Europe (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))


plt.bar(Eu1_df_uk['Year'], Eu1_df_uk['Bipolar Disorders'], color='lightsteelblue', edgecolor='black', label='United Kingdom')
plt.bar(Eu1_df_france['Year'], Eu1_df_france['Bipolar Disorders'], color='lightgreen', edgecolor='black', label='France')
plt.bar(Eu1_df_italy['Year'], Eu1_df_italy['Bipolar Disorders'], color='lightpink', edgecolor='black', label='Italy')
plt.bar(Eu1_df_germany['Year'], Eu1_df_germany['Bipolar Disorders'], color='lightcoral', edgecolor='black', label='Germany')

plt.title('Bipolar Disorders in Europe (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()

plt.figure(figsize=(10, 6))


plt.bar(Eu1_df_italy['Year'], Eu1_df_italy['Eating Disorders'], color='lightpink', edgecolor='black', label='Italy')
plt.bar(Eu1_df_france['Year'], Eu1_df_france['Eating Disorders'], color='lightgreen', edgecolor='black', label='France')
plt.bar(Eu1_df_germany['Year'], Eu1_df_germany['Eating Disorders'], color='lightcoral', edgecolor='black', label='Germany')
plt.bar(Eu1_df_uk['Year'], Eu1_df_uk['Eating Disorders'], color='lightsteelblue', edgecolor='black', label='United Kingdom')
plt.title('Eating Disorders in Europe (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()

# %%
Af_region = 'Africa'
Af_category1 = 'High GDP'
Af_countries1 = ['South Africa']
Af_category2 = 'Medium GDP'
Af_countries2 = ['Algeria']
Af_category3 = 'Low GDP'
Af_countries3 = ['Angola']
subset_dataframes = {}

# High GDP
Af_High = f"{Af_region}_{Af_category1}"
Af1_df = mental[mental['Name'].isin(Af_countries1)].copy() 
subset_dataframes[Af_High] = Af1_df


# Medium GDP
Af_Mid= f"{Af_region}_{Af_category2}"
Af2_df = mental[mental['Name'].isin(Af_countries2)].copy() 
subset_dataframes[Af_Mid] = Af2_df

# Low GDP
Af_Low = f"{Af_region}_{Af_category3}"
Af3_df = mental[mental['Name'].isin(Af_countries3)].copy() 
subset_dataframes[Af_Low] = Af3_df

# %%
# High GDP
Af1_df_south_africa = Af1_df[Af1_df['Name'] == 'South Africa']

plt.figure(figsize=(10, 6))

plt.bar(Af1_df_south_africa['Year'], Af1_df_south_africa['Anxiety Disorders'], color='lightcoral', edgecolor='black', label='South Africa')

plt.title('Anxiety Disorders in Africa (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()

# Repeat the structure for other mental disorders
# ...

# Depressive Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af1_df_south_africa['Year'], Af1_df_south_africa['Depression Disorders'], color='lightcoral', edgecolor='black', label='South Africa')

plt.title('Depressive Disorders in Africa (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Depressive Disorders')
plt.legend()
plt.show()

# Schizophrenia Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af1_df_south_africa['Year'], Af1_df_south_africa['Schizophrenia Disorders'], color='lightcoral', edgecolor='black', label='South Africa')

plt.title('Schizophrenia Disorders in Africa (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

# Bipolar Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af1_df_south_africa['Year'], Af1_df_south_africa['Bipolar Disorders'], color='lightcoral', edgecolor='black', label='South Africa')

plt.title('Bipolar Disorders in Africa (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()

# Eating Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af1_df_south_africa['Year'], Af1_df_south_africa['Eating Disorders'], color='lightcoral', edgecolor='black', label='South Africa')

plt.title('Eating Disorders in Africa (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()

# %%
# Medium GDP
Af2_df_algeria = Af2_df[Af2_df['Name'] == 'Algeria']

plt.figure(figsize=(10, 6))

plt.bar(Af2_df_algeria['Year'], Af2_df_algeria['Anxiety Disorders'], color='lightblue', edgecolor='black', label='Algeria')

plt.title('Anxiety Disorders in Africa (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()

# Repeat the structure for other mental disorders
# ...

# Depressive Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af2_df_algeria['Year'], Af2_df_algeria['Depression Disorders'], color='lightblue', edgecolor='black', label='Algeria')

plt.title('Depressive Disorders in Africa (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Depressive Disorders')
plt.legend()
plt.show()

# Schizophrenia Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af2_df_algeria['Year'], Af2_df_algeria['Schizophrenia Disorders'], color='lightblue', edgecolor='black', label='Algeria')

plt.title('Schizophrenia Disorders in Africa (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

# Bipolar Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af2_df_algeria['Year'], Af2_df_algeria['Bipolar Disorders'], color='lightblue', edgecolor='black', label='Algeria')

plt.title('Bipolar Disorders in Africa (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()

# Eating Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af2_df_algeria['Year'], Af2_df_algeria['Eating Disorders'], color='lightblue', edgecolor='black', label='Algeria')

plt.title('Eating Disorders in Africa (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()

# %%
# Low GDP
Af3_df_angola = Af3_df[Af3_df['Name'] == 'Angola']

plt.figure(figsize=(10, 6))

plt.bar(Af3_df_angola['Year'], Af3_df_angola['Anxiety Disorders'], color='lightgreen', edgecolor='black', label='Angola')

plt.title('Anxiety Disorders in Africa (Low GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()

# Repeat the structure for other mental disorders
# ...

# Depressive Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af3_df_angola['Year'], Af3_df_angola['Depression Disorders'], color='lightgreen', edgecolor='black', label='Angola')

plt.title('Depressive Disorders in Africa (Low GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Depressive Disorders')
plt.legend()
plt.show()

# Schizophrenia Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af3_df_angola['Year'], Af3_df_angola['Schizophrenia Disorders'], color='lightgreen', edgecolor='black', label='Angola')

plt.title('Schizophrenia Disorders in Africa (Low GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

# Bipolar Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af3_df_angola['Year'], Af3_df_angola['Bipolar Disorders'], color='lightgreen', edgecolor='black', label='Angola')

plt.title('Bipolar Disorders in Africa (Low GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()

# Eating Disorders
plt.figure(figsize=(10, 6))

plt.bar(Af3_df_angola['Year'], Af3_df_angola['Eating Disorders'], color='lightgreen', edgecolor='black', label='Angola')

plt.title('Eating Disorders in Africa (Low GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()

# %%
# High GDP
Am1_df_usa = Am1_df[Am1_df['Name'] == 'United States']
Am1_df_canada = Am1_df[Am1_df['Name'] == 'Canada']

plt.figure(figsize=(10, 6))

plt.bar(Am1_df_usa['Year'], Am1_df_usa['Anxiety Disorders'], color='lightcoral', edgecolor='black', label='United States')
plt.bar(Am1_df_canada['Year'], Am1_df_canada['Anxiety Disorders'], color='lightsteelblue', edgecolor='black', label='Canada')

plt.title('Anxiety Disorders in Americas (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()

# Repeat the structure for other mental disorders
# ...

# Depressive Disorders
plt.figure(figsize=(10, 6))

plt.bar(Am1_df_usa['Year'], Am1_df_usa['Depression Disorders'], color='lightcoral', edgecolor='black', label='United States')
plt.bar(Am1_df_canada['Year'], Am1_df_canada['Depression Disorders'], color='lightsteelblue', edgecolor='black', label='Canada')

plt.title('Depressive Disorders in Americas (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Depressive Disorders')
plt.legend()
plt.show()

# Schizophrenia Disorders
plt.figure(figsize=(10, 6))

plt.bar(Am1_df_usa['Year'], Am1_df_usa['Schizophrenia Disorders'], color='lightcoral', edgecolor='black', label='United States')
plt.bar(Am1_df_canada['Year'], Am1_df_canada['Schizophrenia Disorders'], color='lightsteelblue', edgecolor='black', label='Canada')

plt.title('Schizophrenia Disorders in Americas (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

# Bipolar Disorders
plt.figure(figsize=(10, 6))


plt.bar(Am1_df_canada['Year'], Am1_df_canada['Bipolar Disorders'], color='lightsteelblue', edgecolor='black', label='Canada')
plt.bar(Am1_df_usa['Year'], Am1_df_usa['Bipolar Disorders'], color='lightcoral', edgecolor='black', label='United States')

plt.title('Bipolar Disorders in Americas (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()

# Eating Disorders
plt.figure(figsize=(10, 6))

plt.bar(Am1_df_usa['Year'], Am1_df_usa['Eating Disorders'], color='lightcoral', edgecolor='black', label='United States')
plt.bar(Am1_df_canada['Year'], Am1_df_canada['Eating Disorders'], color='lightsteelblue', edgecolor='black', label='Canada')

plt.title('Eating Disorders in Americas (High GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()

# %%
# Medium GDP
Am2_df_argentina = Am2_df[Am2_df['Name'] == 'Argentina']

plt.figure(figsize=(10, 6))

plt.bar(Am2_df_argentina['Year'], Am2_df_argentina['Anxiety Disorders'], color='lightcoral', edgecolor='black', label='Argentina')

plt.title('Anxiety Disorders in Americas (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()

# Repeat the structure for other mental disorders
# ...

# Depressive Disorders
plt.figure(figsize=(10, 6))

plt.bar(Am2_df_argentina['Year'], Am2_df_argentina['Depression Disorders'], color='lightcoral', edgecolor='black', label='Argentina')

plt.title('Depressive Disorders in Americas (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Depressive Disorders')
plt.legend()
plt.show()

# Schizophrenia Disorders
plt.figure(figsize=(10, 6))

plt.bar(Am2_df_argentina['Year'], Am2_df_argentina['Schizophrenia Disorders'], color='lightcoral', edgecolor='black', label='Argentina')

plt.title('Schizophrenia Disorders in Americas (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

# Bipolar Disorders
plt.figure(figsize=(10, 6))

plt.bar(Am2_df_argentina['Year'], Am2_df_argentina['Bipolar Disorders'], color='lightcoral', edgecolor='black', label='Argentina')

plt.title('Bipolar Disorders in Americas (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()

# Eating Disorders
plt.figure(figsize=(10, 6))

plt.bar(Am2_df_argentina['Year'], Am2_df_argentina['Eating Disorders'], color='lightcoral', edgecolor='black', label='Argentina')

plt.title('Eating Disorders in Americas (Medium GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()

# %%
# Low GDP
Am3_df_jamaica = Am3_df[Am3_df['Name'] == 'Jamaica']
Am3_df_america_ihme = Am3_df[Am3_df['Name'] == 'America (IHME GBD)']
Am3_df_american_samoa = Am3_df[Am3_df['Name'] == 'American Samoa']

plt.figure(figsize=(10, 6))


plt.bar(Am3_df_america_ihme['Year'], Am3_df_america_ihme['Anxiety Disorders'], color='lightsteelblue', edgecolor='black', label='America (IHME GBD)')
plt.bar(Am3_df_american_samoa['Year'], Am3_df_american_samoa['Anxiety Disorders'], color='lightgreen', edgecolor='black', label='American Samoa')
plt.bar(Am3_df_jamaica['Year'], Am3_df_jamaica['Anxiety Disorders'], color='lightcoral', edgecolor='black', label='Jamaica')
plt.title('Anxiety Disorders in Americas (Low GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Anxiety Disorders')
plt.legend()
plt.show()

# Depressive Disorders
plt.figure(figsize=(10, 6))


plt.bar(Am3_df_america_ihme['Year'], Am3_df_america_ihme['Depression Disorders'], color='lightsteelblue', edgecolor='black', label='America (IHME GBD)')

plt.bar(Am3_df_jamaica['Year'], Am3_df_jamaica['Depression Disorders'], color='lightcoral', edgecolor='black', label='Jamaica')
plt.bar(Am3_df_american_samoa['Year'], Am3_df_american_samoa['Depression Disorders'], color='lightgreen', edgecolor='black', label='American Samoa')

plt.title('Depressive Disorders in Americas (Low GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Depressive Disorders')
plt.legend()
plt.show()

# Schizophrenia Disorders
plt.figure(figsize=(10, 6))

plt.bar(Am3_df_america_ihme['Year'], Am3_df_america_ihme['Schizophrenia Disorders'], color='lightsteelblue', edgecolor='black', label='America (IHME GBD)')
plt.bar(Am3_df_american_samoa['Year'], Am3_df_american_samoa['Schizophrenia Disorders'], color='lightgreen', edgecolor='black', label='American Samoa')
plt.bar(Am3_df_jamaica['Year'], Am3_df_jamaica['Schizophrenia Disorders'], color='lightcoral', edgecolor='black', label='Jamaica')

plt.title('Schizophrenia Disorders in Americas (Low GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Schizophrenia Disorders')
plt.legend()
plt.show()

# Bipolar Disorders
plt.figure(figsize=(10, 6))

plt.bar(Am3_df_jamaica['Year'], Am3_df_jamaica['Bipolar Disorders'], color='lightcoral', edgecolor='black', label='Jamaica')
plt.bar(Am3_df_america_ihme['Year'], Am3_df_america_ihme['Bipolar Disorders'], color='lightsteelblue', edgecolor='black', label='America (IHME GBD)')
plt.bar(Am3_df_american_samoa['Year'], Am3_df_american_samoa['Bipolar Disorders'], color='lightgreen', edgecolor='black', label='American Samoa')

plt.title('Bipolar Disorders in Americas (Low GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Bipolar Disorders')
plt.legend()
plt.show()

# Eating Disorders
plt.figure(figsize=(10, 6))


plt.bar(Am3_df_america_ihme['Year'], Am3_df_america_ihme['Eating Disorders'], color='lightsteelblue', edgecolor='black', label='America (IHME GBD)')
plt.bar(Am3_df_jamaica['Year'], Am3_df_jamaica['Eating Disorders'], color='lightcoral', edgecolor='black', label='Jamaica')
plt.bar(Am3_df_american_samoa['Year'], Am3_df_american_samoa['Eating Disorders'], color='lightgreen', edgecolor='black', label='American Samoa')
plt.title('Eating Disorders in Americas (Low GDP) - 1990 to 2019')
plt.xlabel('Year')
plt.ylabel('Eating Disorders')
plt.legend()
plt.show()
